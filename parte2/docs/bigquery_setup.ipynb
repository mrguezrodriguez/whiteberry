# %%
from google.cloud import bigquery
from google.oauth2 import service_account
import os
from dotenv import load_dotenv
from pathlib import Path

# Desde parte2/docs/ subimos dos niveles hasta la raíz del proyecto
BASE_DIR = Path(os.getcwd()).parent.parent

load_dotenv(dotenv_path=BASE_DIR / ".env")

# Configuración
PROJECT_ID = os.getenv("GCP_PROJECT_ID")
DATASET_ID = os.getenv("BQ_DATASET_ID")
CREDENTIALS_PATH = BASE_DIR / "parte2" / "credentials" / "service-account.json"

# Cliente autenticado
credentials = service_account.Credentials.from_service_account_file(
    str(CREDENTIALS_PATH)
)
client = bigquery.Client(
    project=PROJECT_ID,
    credentials=credentials
)

# Crear dataset
dataset_ref = bigquery.Dataset(f"{PROJECT_ID}.{DATASET_ID}")
dataset_ref.location = "EU"
dataset = client.create_dataset(dataset_ref, exists_ok=True)
print(f"Dataset {DATASET_ID} creado")
# Out:
# Dataset whiteberry creado

# %%
load_dotenv(dotenv_path=Path(os.getcwd()).parent.parent / ".env")

print("PROJECT:", os.getenv("GCP_PROJECT_ID"))
print("DATASET:", os.getenv("BQ_DATASET_ID"))
print("CREDENTIALS:", os.getenv("GOOGLE_APPLICATION_CREDENTIALS"))
# Out:
# PROJECT: whiteberry-network
# DATASET: whiteberry
# CREDENTIALS: ./credentials/service-account.json
